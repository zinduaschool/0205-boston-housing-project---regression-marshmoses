# %%
import matplotlib.pyplot as plt

# Production capacities
germany_pork = 18  # million tonnes
germany_pv = 22  # units

china_pork = 148  # million tonnes
china_pv = 30  # units

# Calculate opportunity costs
opp_cost_germany_pork = germany_pv / germany_pork
opp_cost_china_pork = china_pv / china_pork

opp_cost_germany_pv = germany_pork / germany_pv
opp_cost_china_pv = china_pork / china_pv

# Plotting the PPF
plt.figure(figsize=(10, 6))

plt.plot([0, germany_pork], [germany_pv, 0], label='Germany PPF')
plt.plot([0, china_pork], [china_pv, 0], label='China PPF')

plt.scatter(germany_pork, germany_pv, color='red', marker='o')
plt.text(germany_pork, germany_pv, ' Germany', ha='right', va='bottom', color='red')

plt.scatter(china_pork, china_pv, color='blue', marker='o')
plt.text(china_pork, china_pv, ' China', ha='right', va='bottom', color='blue')

plt.title('Production Possibilities Frontier')
plt.xlabel('Pork Production (million tonnes)')
plt.ylabel('PV Module Production (units)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import openpyxl
from openpyxl.chart import ScatterChart, Reference, Series

# Create a new Excel workbook
wb = openpyxl.Workbook()
ws = wb.active

# Add headers
ws['A1'] = 'Country'
ws['B1'] = 'Pork Production (million tonnes)'
ws['C1'] = 'PV Module Production (units)'

# Add data
data = [
    ('Germany', 18, 22),
    ('China', 148, 30),
]

for row in data:
    ws.append(row)

# Create a scatter chart
chart = ScatterChart()
chart.title = "Production Possibilities Frontier"
chart.x_axis.title = "Pork Production (million tonnes)"
chart.y_axis.title = "PV Module Production (units)"

# Add series to the chart
for row_num in range(2, len(data) + 2):
    series = Series(Reference(ws, min_col=2, min_row=row_num, max_col=3, max_row=row_num), title_from_data=True)
    chart.series.append(series)

# Add chart to the worksheet
ws.add_chart(chart, "E5")

# Save the Excel file
wb.save("PPF_Chart.xlsx")

# %%
import openpyxl
from openpyxl.chart import ScatterChart, Reference, Series

# Create a new Excel workbook
wb = openpyxl.Workbook()
ws = wb.active

# Add headers
ws['A1'] = 'Country'
ws['B1'] = 'Pork Production (million tonnes)'
ws['C1'] = 'PV Module Production (units)'

# Add data
data = [
    ('Germany', 18, 22),
    ('China', 148, 30),
]

for row in data:
    ws.append(row)

# Create a scatter chart
chart = ScatterChart()
chart.title = "Production Possibilities Frontier"
chart.x_axis.title = "Pork Production (million tonnes)"
chart.y_axis.title = "PV Module Production (units)"

# Add series to the chart
for row_num in range(2, len(data) + 2):
    xvalues = Reference(ws, min_col=2, min_row=row_num, max_col=2)
    yvalues = Reference(ws, min_col=3, min_row=row_num, max_col=3)
    series = Series(yvalues, xvalues, title_from_data=True)
    chart.series.append(series)

# Add chart to the worksheet
ws.add_chart(chart, "E5")

# Save the Excel file
wb.save("PPF_Chart1.xlsx")
plt.show()

# %%
import openpyxl
from openpyxl.chart import LineChart, Reference, Series

# Create a new Excel workbook
wb = openpyxl.Workbook()
ws = wb.active

# Add headers
ws['A1'] = 'Country'
ws['B1'] = 'Pork Production (million tonnes)'
ws['C1'] = 'PV Module Production (units)'

# Add data
data = [
    ('Germany', 18, 22),
    ('China', 148, 30),
]

for row in data:
    ws.append(row)

# Create a line chart
chart = LineChart()
chart.title = "Production Possibilities Frontier"
chart.x_axis.title = "Pork Production (million tonnes)"
chart.y_axis.title = "PV Module Production (units)"

# Add series to the chart
for row_num in range(2, len(data) + 2):
    xvalues = Reference(ws, min_col=2, min_row=row_num, max_col=2)
    yvalues = Reference(ws, min_col=3, min_row=row_num, max_col=3)
    series = Series(yvalues, xvalues, title_from_data=True)
    chart.series.append(series)

# Add chart to the worksheet
ws.add_chart(chart, "E5")

# Save the Excel file
wb.save("PPF_LineChart.xlsx")

# %%
import openpyxl
from openpyxl.chart import LineChart, Reference

# Create a new Excel workbook
wb = openpyxl.Workbook()
ws = wb.active

# Add headers
ws['A1'] = 'Country'
ws['B1'] = 'Pork Production (million tonnes)'
ws['C1'] = 'PV Module Production (units)'

# Add data
data = [
    ('Germany', 18, 22),
    ('China', 148, 30),
]

for row in data:
    ws.append(row)

# Create a line chart with markers
chart = LineChart()
chart.title = "Production Possibilities Frontier"
chart.x_axis.title = "Pork Production (million tonnes)"
chart.y_axis.title = "PV Module Production (units)"
chart.style = 13  # Line chart with markers

# Add data series to the chart
for row_num in range(2, len(data) + 2):
    chart.add_data(
        Reference(ws, min_col=2, min_row=row_num, max_col=3, max_row=row_num),
        titles_from_data=True,
    )

# Add chart to the worksheet
ws.add_chart(chart, "E5")

# Save the Excel file
wb.save("PPF_LineChart_Markers.xlsx")

# %%
import openpyxl
from openpyxl.chart import LineChart, Reference

# Create a new Excel workbook
wb = openpyxl.Workbook()
ws = wb.active

# Add headers
ws['A1'] = 'Country'
ws['B1'] = 'Pork Production (million tonnes)'
ws['C1'] = 'PV Module Production (units)'

# Add data
data = [
    ('Germany', 18, 22),
    ('China', 148, 30),
]

for row in data:
    ws.append(row)

# Create a line chart with markers
chart = LineChart()
chart.title = "Production Possibilities Frontier"
chart.x_axis.title = "Pork Production (million tonnes)"
chart.y_axis.title = "PV Module Production (units)"
chart.style = 13  # Line chart with markers

# Add data series to the chart
for row_num in range(2, len(data) + 2):
    chart.add_data(
        Reference(ws, min_col=2, min_row=row_num, max_col=2, max_row=row_num),
        titles_from_data=True,
    )

# Add chart to the worksheet
ws.add_chart(chart, "E5")

# Save the Excel file
wb.save("PPF_LineChart_Pork_vs_PV.xlsx")

# %%
import openpyxl
from openpyxl.chart import LineChart, Reference

# Create a new Excel workbook
wb = openpyxl.Workbook()
ws = wb.active

# Add headers
ws['A1'] = 'Country'
ws['B1'] = 'Pork Production (million tonnes)'
ws['C1'] = 'PV Module Production (units)'

# Add data
data = [
    ('Germany', 18, 22),
    ('China', 148, 30),
]

for row in data:
    ws.append(row)

# Create a line chart with markers
chart = LineChart()
chart.title = "Production Possibilities Frontier"
chart.x_axis.title = "Country"
chart.y_axis.title = "Production"
chart.style = 13  # Line chart with markers

# Add data series to the chart
for row_num in range(2, len(data) + 2):
    chart.add_data(
        Reference(ws, min_col=3, min_row=row_num, max_col=3, max_row=row_num),
        titles_from_data=True,
    )

# Set categories explicitly for the x-axis
categories = Reference(ws, min_col=1, min_row=2, max_row=len(data) + 1)
chart.set_categories(categories)

# Add chart to the worksheet
ws.add_chart(chart, "E5")

# Save the Excel file
wb.save("PPF_LineChart_Pork_vs_PV1.xlsx")

# %%
import openpyxl
from openpyxl.chart import LineChart, Reference

# Create a new Excel workbook
wb = openpyxl.Workbook()
ws = wb.active

# Add headers
ws['A1'] = 'Country'
ws['B1'] = 'Pork Production (million tonnes)'
ws['C1'] = 'PV Module Production (units)'

# Add data
data = [
    ('Germany', 18, 22),
    ('China', 148, 30),
]

for row in data:
    ws.append(row)

# Create a line chart with markers
chart = LineChart()
chart.title = "Production Possibilities Frontier"
chart.x_axis.title = "PV Module Production (units)"
chart.y_axis.title = "Pork Production (million tonnes)"
chart.style = 13  # Line chart with markers

# Add data series to the chart
for row_num in range(2, len(data) + 2):
    chart.add_data(
        Reference(ws, min_col=3, min_row=row_num, max_col=3, max_row=row_num),
        titles_from_data=True,
        categories=Reference(ws, min_col=2, min_row=row_num, max_col=2, max_row=row_num),
    )

# Add chart to the worksheet
ws.add_chart(chart, "E5")

# Save the Excel file
wb.save("PPF_LineChart_PV_vs_Pork1.xlsx")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 31
#      29 # Add data series to the chart
#      30 for row_num in range(2, len(data) + 2):
# ---> 31     chart.add_data(
#      32         Reference(ws, min_col=3, min_row=row_num, max_col=3, max_row=row_num),
#      33         titles_from_data=True,
#      34         categories=Reference(ws, min_col=2, min_row=row_num, max_col=2, max_row=row_num),
#      35     )
#      37 # Add chart to the worksheet
#      38 ws.add_chart(chart, "E5")
#
# TypeError: ChartBase.add_data() got an unexpected keyword argument 'categories'

# %%
import matplotlib.pyplot as plt

# Data
countries = ['Germany', 'China']
pork_production = [18, 148]
pv_production = [22, 30]

# Plotting the graph
plt.figure(figsize=(8, 6))
plt.plot(pv_production, pork_production, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('PV Module Production (units)')
plt.ylabel('Pork Production (million tonnes)')
plt.title('Production Possibilities Frontier')

# Adding country labels to the points
for i, country in enumerate(countries):
    plt.annotate(country, (pv_production[i], pork_production[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Save the graph to a PDF file
plt.savefig("PPF_Graph.pdf", format='pdf')

# Display the graph
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
countries = ['Germany', 'China']
pork_production = [18, 148]
pv_production = [22, 30]

# Plotting the graph
plt.figure(figsize=(8, 6))

# Plot line for Germany
plt.plot(pv_production[0], pork_production[0], marker='o', linestyle='-', color='b', label='Germany')

# Plot line for China
plt.plot(pv_production[1], pork_production[1], marker='o', linestyle='-', color='r', label='China')

# Adding labels and title
plt.xlabel('PV Module Production (units)')
plt.ylabel('Pork Production (million tonnes)')
plt.title('Production Possibilities Frontier')

# Adding country labels to the points
for i, country in enumerate(countries):
    plt.annotate(country, (pv_production[i], pork_production[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Show legend
plt.legend()

# Save the graph to a PDF file
plt.savefig("PPF_Graph1.pdf", format='pdf')

# Display the graph
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
countries = ['Germany', 'China']
pork_production = [18, 148]
pv_production = [22, 30]

# Plotting the graph
plt.figure(figsize=(8, 6))

# Plot line for Germany
plt.plot(pv_production[0], pork_production[0], marker='o', linestyle='-', color='b', label='Germany')

# Plot line for China
plt.plot(pv_production[1], pork_production[1], marker='o', linestyle='-', color='r', label='China')

# Adding labels and title
plt.xlabel('PV Module Production (units)')
plt.ylabel('Pork Production (million tonnes)')
plt.title('Production Possibilities Frontier')

# Adding country labels to the points
for i, country in enumerate(countries):
    plt.annotate(country, (pv_production[i], pork_production[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Show legend
plt.legend()

# Save the graph to a PDF file
plt.savefig("PPF_Graph2.pdf", format='pdf')

# Display the graph
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
countries = ['Germany', 'China']
pork_production = [18, 148]
pv_production = [22, 30]

# Plotting the graph
plt.figure(figsize=(8, 6))

# Plot line for Germany
plt.plot(pv_production[:1], pork_production[:1], marker='o', linestyle='-', color='b', label='Germany')

# Plot line for China
plt.plot(pv_production[1:], pork_production[1:], marker='o', linestyle='-', color='r', label='China')

# Adding labels and title
plt.xlabel('PV Module Production (units)')
plt.ylabel('Pork Production (million tonnes)')
plt.title('Production Possibilities Frontier')

# Adding country labels to the points
for i, country in enumerate(countries):
    plt.annotate(country, (pv_production[i], pork_production[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Show legend
plt.legend()

# Save the graph to a PDF file
plt.savefig("PPF_Graph3.pdf", format='pdf')

# Display the graph
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
countries = ['Germany', 'China']
pork_production = [18, 148]
pv_production = [22, 30]

# Plotting the graph
plt.figure(figsize=(8, 6))

# Plot line connecting Germany and China
plt.plot(pv_production, pork_production, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('PV Module Production (units)')
plt.ylabel('Pork Production (million tonnes)')
plt.title('Production Possibilities Frontier')

# Adding country labels to the points
for i, country in enumerate(countries):
    plt.annotate(country, (pv_production[i], pork_production[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Save the graph to a PDF file
plt.savefig("PPF_Graph4.pdf", format='pdf')

# Display the graph
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
countries = ['Germany', 'China']
pork_production = [18, 148]
pv_production = [22, 30]

# Plotting the graph
plt.figure(figsize=(8, 6))

# Plot PPF for Germany
plt.plot(pv_production[:1], pork_production[:1], marker='o', linestyle='-', color='b', label='Germany')

# Plot PPF for China
plt.plot(pv_production[1:], pork_production[1:], marker='o', linestyle='-', color='r', label='China')

# Adding labels and title
plt.xlabel('PV Module Production (units)')
plt.ylabel('Pork Production (million tonnes)')
plt.title('Production Possibilities Frontier')

# Adding country labels to the points
for i, country in enumerate(countries):
    plt.annotate(country, (pv_production[i], pork_production[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Show legend
plt.legend()

# Save the graph to a PDF file
plt.savefig("PPF_Graph_Two_PPFs.pdf", format='pdf')

# Display the graph
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Production capacities
germany_pork = 18  # million tonnes
germany_pv = 22  # units

china_pork = 148  # million tonnes
china_pv = 30  # units

# Calculate opportunity costs
opp_cost_germany_pork = germany_pv / germany_pork
opp_cost_china_pork = china_pv / china_pork

opp_cost_germany_pv = germany_pork / germany_pv
opp_cost_china_pv = china_pork / china_pv

# Plotting the PPF
plt.figure(figsize=(10, 6))

plt.plot([0, germany_pork], [germany_pv, 0], label='Germany PPF', color='red')
plt.plot([0, china_pork], [china_pv, 0], label='China PPF', color='blue')

plt.scatter(germany_pork, germany_pv, color='red', marker='o')
plt.text(germany_pork, germany_pv, ' Germany', ha='right', va='bottom', color='red')

plt.scatter(china_pork, china_pv, color='blue', marker='o')
plt.text(china_pork, china_pv, ' China', ha='right', va='bottom', color='blue')

plt.title('Production Possibilities Frontier')
plt.xlabel('Pork Production (million tonnes)')
plt.ylabel('PV Module Production (units)')
plt.legend()
plt.grid(True)

# Save the graph to a PDF file
plt.savefig("PPF_Graph5.pdf", format='pdf')

# Display the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
countries = ['China', 'Germany']
arable_land = [134, 16.6]  # in million hectares
pork_production = [148888889, 18444444]  # in tonnes
pv_production = [30, 20]  # in units
pv_capital = [45, 7.7]  # in billion euros

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle('Comparison between China and Germany')

# Subplot 1: Arable Land Comparison
axs[0, 0].bar(countries, arable_land, color=['blue', 'orange'])
axs[0, 0].set_ylabel('Arable Land (million hectares)')

# Subplot 2: Pork Production Comparison
axs[0, 1].bar(countries, pork_production, color=['blue', 'orange'])
axs[0, 1].set_ylabel('Pork Production (tonnes)')

# Subplot 3: PV Module Production Comparison
axs[1, 0].bar(countries, pv_production, color=['blue', 'orange'])
axs[1, 0].set_ylabel('PV Module Production (units)')

# Subplot 4: PV Capital Comparison
axs[1, 1].bar(countries, pv_capital, color=['blue', 'orange'])
axs[1, 1].set_ylabel('PV Capital (billion euros)')

# Save the plots to a PDF file
plt.savefig("Comparison_China_Germany.pdf", format='pdf')

# Show the plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
countries = ['China', 'Germany']
arable_land = [134, 16.6]  # in million hectares
pork_production = [148888889, 18444444]  # in tonnes
pv_production = [30, 20]  # in units
pv_capital = [45, 7.7]  # in billion euros

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle('Comparison between China and Germany')

# Subplot 1: Arable Land Comparison
axs[0, 0].plot(countries, arable_land, marker='o', label='Arable Land')
axs[0, 0].set_ylabel('Arable Land (million hectares)')

# Subplot 2: Pork Production Comparison
axs[0, 1].plot(countries, pork_production, marker='o', label='Pork Production')
axs[0, 1].set_ylabel('Pork Production (tonnes)')

# Subplot 3: PV Module Production Comparison
axs[1, 0].plot(countries, pv_production, marker='o', label='PV Module Production')
axs[1, 0].set_ylabel('PV Module Production (units)')

# Subplot 4: PV Capital Comparison
axs[1, 1].plot(countries, pv_capital, marker='o', label='PV Capital')
axs[1, 1].set_ylabel('PV Capital (billion euros)')

# Add legend
for ax in axs.flat:
    ax.legend()

# Save the plots to a PDF file
plt.savefig("Comparison_China_Germany_Line1.pdf", format='pdf')

# Show the plots
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for China
china_pork = 148888889  # tonnes
china_pv = 30  # units
china_arable_land = 134  # million hectares

# Data for Germany
germany_pork = 18444444  # tonnes
germany_pv = 20  # units
germany_arable_land = 16.6  # million hectares

# Calculate land efficiency for each country
land_efficiency_china = china_arable_land / china_pork
land_efficiency_germany = germany_arable_land / germany_pork

# Calculate PV efficiency for each country
pv_efficiency_china = china_pv / china_pork
pv_efficiency_germany = germany_pv / germany_pork

# Plotting the PPF for China
plt.figure(figsize=(10, 6))

# Plotting the PPF line
plt.plot([0, land_efficiency_china], [china_pv, 0], label='China PPF')
plt.scatter(land_efficiency_china, china_pv, color='red', marker='o')
plt.text(land_efficiency_china, china_pv, ' China', ha='right', va='bottom', color='red')

# Labels and title
plt.title('Production Possibilities Frontier - China')
plt.xlabel('Land Efficiency (million hectares per tonne)')
plt.ylabel('PV Module Production (units)')

plt.legend()
plt.grid(True)
plt.show()

# Plotting the PPF for Germany
plt.figure(figsize=(10, 6))

# Plotting the PPF line
plt.plot([0, land_efficiency_germany], [germany_pv, 0], label='Germany PPF')
plt.scatter(land_efficiency_germany, germany_pv, color='blue', marker='o')
plt.text(land_efficiency_germany, germany_pv, ' Germany', ha='right', va='bottom', color='blue')

# Labels and title
plt.title('Production Possibilities Frontier - Germany')
plt.xlabel('Land Efficiency (million hectares per tonne)')
plt.ylabel('PV Module Production (units)')

plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for China
china_pork = 148888889  # tonnes
china_pv = 30  # units
china_arable_land = 134  # million hectares

# Data for Germany
germany_pork = 18444444  # tonnes
germany_pv = 20  # units
germany_arable_land = 16.6  # million hectares

# Calculate land efficiency for each country
land_efficiency_china = china_arable_land / china_pork
land_efficiency_germany = germany_arable_land / germany_pork

# Calculate PV efficiency for each country
pv_efficiency_china = china_pv / china_pork
pv_efficiency_germany = germany_pv / germany_pork

# Plotting the PPF for China and Germany
plt.figure(figsize=(10, 6))

# Plotting the PPF lines
plt.plot([0, land_efficiency_china], [china_pv, 0], label='China PPF', color='red', marker='o')
plt.plot([0, land_efficiency_germany], [germany_pv, 0], label='Germany PPF', color='blue', marker='o')

# Labels and title
plt.title('Production Possibilities Frontier Comparison')
plt.xlabel('Land Efficiency (million hectares per tonne)')
plt.ylabel('PV Module Production (units)')

# Add country labels
plt.text(land_efficiency_china, china_pv, ' China', ha='right', va='bottom', color='red')
plt.text(land_efficiency_germany, germany_pv, ' Germany', ha='right', va='bottom', color='blue')

plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for China
china_pork = 148888889  # tonnes
china_pv = 30  # units
china_arable_land = 134  # million hectares

# Data for Germany
germany_pork = 18444444  # tonnes
germany_pv = 20  # units
germany_arable_land = 16.6  # million hectares

# Calculate land efficiency for each country
land_efficiency_china = china_arable_land / china_pork
land_efficiency_germany = germany_arable_land / germany_pork

# Calculate PV efficiency for each country
pv_efficiency_china = china_pv / china_pork
pv_efficiency_germany = germany_pv / germany_pork

# Set the maximum limit for the x-axis
max_x = max(land_efficiency_china, land_efficiency_germany) + 0.5

# Set the maximum limit for the y-axis
max_y = max(china_pv, germany_pv) + 5

# Plotting the PPF for China and Germany
plt.figure(figsize=(10, 6))

# Plotting the PPF lines
plt.plot([0, land_efficiency_china], [china_pv, 0], label='China PPF', color='red', marker='o')
plt.plot([0, land_efficiency_germany], [germany_pv, 0], label='Germany PPF', color='blue', marker='o')

# Labels and title
plt.title('Production Possibilities Frontier Comparison')
plt.xlabel('Land Efficiency (million hectares per tonne)')
plt.ylabel('PV Module Production (units)')

# Set the x-axis and y-axis limits
plt.xlim(0, max_x)
plt.ylim(0, max_y)

# Add country labels
plt.text(land_efficiency_china, china_pv, ' China', ha='right', va='bottom', color='red')
plt.text(land_efficiency_germany, germany_pv, ' Germany', ha='right', va='bottom', color='blue')

# Add a grid
plt.grid(True)

# Add legend
plt.legend()

plt.show()
